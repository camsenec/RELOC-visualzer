# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
servers = pd.read_csv("serverResult.csv", names = ["application_id", "server_id", "x", "y", "capacity", "connection", "used", "MP", "cluster_id"])

# %%
servers.sort_values(by = "cluster_id")
# Out:
#     application_id  server_id          x          y  capacity  connection  \
# 29               1         30  76.936213  94.991400       160           7
# 88               1         89  63.825523  76.260210       160           3
# 63               1         64  82.988093  87.861948       160           8
# 84               1         85  84.731219  96.846722       160          19
# 83               1         84  66.216446  87.931692       160           1
# ..             ...        ...        ...        ...       ...         ...
# 82               1         83  58.356395  10.769781       160          10
# 67               1         68  64.221115  25.279306       160           2
# 10               1         11  67.239482   9.203367       160          38
# 48               1         49  60.379569  23.026315       160           8
# 40               1         41  66.231800  13.166632       160           5
#
#     used   MP  cluster_id
# 29   128  119           0
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(data = servers, x = "used")
# Out:
# <AxesSubplot:xlabel='used', ylabel='Count'>
